# %%
# import libraries
import pandas as pd
import glob
import os
import plotly.express as px

# %%
# load and combine datasets
csv_files = glob.glob('../data-files/Price-Data/*.csv', recursive=True)

dataframes = []

for file in csv_files:
    df = pd.read_csv(file)

    # add metadata columns
    filename = os.path.basename(file).replace('.csv', '')
    parts = filename.split('_')

    symbol = parts[0]
    name = '_'.join(parts[1:])
    
    df['Symbol'] = symbol
    df['Name'] = name

    dataframes.append(df)

combined_df = pd.concat(dataframes, ignore_index=True)
combined_df
# Out:
#                Date      Open      High       Low     Close  Adj Close  \
# 0        2020-12-25  1.602781  2.918094  1.375262  2.328544   2.328544
# 1        2020-12-26  2.318946  2.434916  1.582264  1.596896   1.596896
# 2        2020-12-27  1.597744  1.630781  1.056657  1.062112   1.062112
# 3        2020-12-28  1.064454  1.254447  1.049051  1.110076   1.110076
# 4        2020-12-29  1.110460  1.111282  0.761151  0.887798   0.887798
# ...             ...       ...       ...       ...       ...        ...
# 1120381  2023-05-21  0.200783  0.202872  0.170214  0.192276   0.192276
# 1120382  2023-05-22  0.192269  0.224723  0.185978  0.220389   0.220389
# 1120383  2023-05-23  0.220390  0.234141  0.185507  0.218141   0.218141
# 1120384  2023-05-24  0.218146  0.222411  0.196359  0.200213   0.200213
# 1120385  2023-05-25  0.199944  0.219885  0.192364  0.193309   0.193309
#
#             Volume Symbol           Name
# 0        638225549  1INCH  1inch-Network
# 1        237653073  1INCH  1inch-Network
# 2        183978307  1INCH  1inch-Network
# 3        119337529  1INCH  1inch-Network
# 4        137916899  1INCH  1inch-Network
# ...            ...    ...            ...
# 1120381      32333    ZYN       Zynecoin
# 1120382      20047    ZYN       Zynecoin
# 1120383      21877    ZYN       Zynecoin
# 1120384      19095    ZYN       Zynecoin
# 1120385      29634    ZYN       Zynecoin
#
# [1120386 rows x 9 columns]

# %%
# reorder columns
new_order = ['Date', 'Name', 'Symbol', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']

# Terapkan ke dataframe
combined_df = combined_df[new_order]
combined_df
# Out:
#                Date           Name Symbol      Open      High       Low  \
# 0        2020-12-25  1inch-Network  1INCH  1.602781  2.918094  1.375262
# 1        2020-12-26  1inch-Network  1INCH  2.318946  2.434916  1.582264
# 2        2020-12-27  1inch-Network  1INCH  1.597744  1.630781  1.056657
# 3        2020-12-28  1inch-Network  1INCH  1.064454  1.254447  1.049051
# 4        2020-12-29  1inch-Network  1INCH  1.110460  1.111282  0.761151
# ...             ...            ...    ...       ...       ...       ...
# 1120381  2023-05-21       Zynecoin    ZYN  0.200783  0.202872  0.170214
# 1120382  2023-05-22       Zynecoin    ZYN  0.192269  0.224723  0.185978
# 1120383  2023-05-23       Zynecoin    ZYN  0.220390  0.234141  0.185507
# 1120384  2023-05-24       Zynecoin    ZYN  0.218146  0.222411  0.196359
# 1120385  2023-05-25       Zynecoin    ZYN  0.199944  0.219885  0.192364
#
#             Close  Adj Close     Volume
# 0        2.328544   2.328544  638225549
# 1        1.596896   1.596896  237653073
# 2        1.062112   1.062112  183978307
# 3        1.110076   1.110076  119337529
# 4        0.887798   0.887798  137916899
# ...           ...        ...        ...
# 1120381  0.192276   0.192276      32333
# 1120382  0.220389   0.220389      20047
# 1120383  0.218141   0.218141      21877
# 1120384  0.200213   0.200213      19095
# 1120385  0.193309   0.193309      29634
#
# [1120386 rows x 9 columns]

# %%
combined_df.isnull().sum()
# Out:
# Date         0
# Name         0
# Symbol       0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
combined_df.dtypes
# Out:
# Date          object
# Name          object
# Symbol        object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
combined_df['Date'] = pd.to_datetime(combined_df['Date'])

# %%
combined_df.dtypes
# Out:
# Date         datetime64[ns]
# Name                 object
# Symbol               object
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume                int64
# dtype: object

# %%
combined_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# descriptive analysis
combined_df.describe()
# Out:
#                                 Date          Open          High  \
# count                        1120386  1.120386e+06  1.120386e+06
# mean   2021-06-18 01:17:51.164401920  2.914649e+02  3.161270e+02
# min              2014-09-17 00:00:00  0.000000e+00  0.000000e+00
# 25%              2020-07-27 00:00:00  2.482025e-02  2.628825e-02
# 50%              2021-10-09 00:00:00  2.180980e-01  2.303730e-01
# 75%              2022-08-13 00:00:00  1.497100e+00  1.585804e+00
# max              2023-05-25 00:00:00  1.710106e+05  1.453542e+07
# std                              NaN  3.376870e+03  1.420463e+04
#
#                 Low         Close     Adj Close        Volume
# count  1.120386e+06  1.120386e+06  1.120386e+06  1.120386e+06
# mean   2.805463e+02  2.915729e+02  2.915729e+02  3.520449e+08
# min   -1.706356e+03  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    2.340600e-02  2.479525e-02  2.479525e-02  2.484972e+05
# 50%    2.067610e-01  2.178585e-01  2.178585e-01  1.761296e+06
# 75%    1.411921e+00  1.495099e+00  1.495099e+00  1.150852e+07
# max    1.486707e+05  1.709341e+05  1.709341e+05  8.325207e+13
# std    3.235830e+03  3.377036e+03  3.377036e+03  1.077807e+11

# %%
zero_counts = (combined_df[['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']] == 0).sum()
print("result of zero value per column:\n", zero_counts)
# Out:
# result of zero value per column:
#  Open          7531
# High          7352
# Low           7696
# Close         7513
# Adj Close     7513
# Volume       13072
# dtype: int64

# %%
# rows with negative value
print("rows with negative value:\n")
print(combined_df[(combined_df[['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']] < 0).any(axis=1)].head())

# rows with zero value
print("\n rows with zeroes value:\n")
print(combined_df[(combined_df[['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']] == 0).any(axis=1)].head())
# Out:
# rows with negative value:
#
#              Date      Name Symbol        Open        High          Low  \
# 281704 2021-11-10  DigixDAO    DGD  903.631042  914.066956 -1706.356079
#
#              Close   Adj Close  Volume
# 281704  849.204651  849.204651   46670
#
#  rows with zeroes value:
#
#            Date           Name Symbol      Open      High       Low     Close  \
# 993  2021-11-16  1-UP-Platform      1  0.172156  1.199404  0.000000  0.166900
# 994  2021-11-17  1-UP-Platform      1  0.166857  0.291655  0.000000  0.163522
# 1177 2022-05-19  1-UP-Platform      1  0.031781  0.033644  0.031602  0.033501
# 1192 2022-06-03  1-UP-Platform      1  0.028221  0.028224  0.026785  0.027255
# 1199 2022-06-10  1-UP-Platform      1  0.029922  0.030103  0.027797  0.027800
#
#       Adj Close  Volume
# 993    0.166900  356633
# 994    0.163522  142084
# 1177   0.033501       0
# 1192   0.027255       0
# 1199   0.027800       0

# %%
# data cleaning
combined_df = combined_df[
    (combined_df['Open'] >= 0) &
    (combined_df['High'] >= 0) &
    (combined_df['Low'] >= 0) &
    (combined_df['Close'] >= 0) &
    (combined_df['Adj Close'] >= 0)
]

combined_df = combined_df[
    (combined_df[['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']] != 0).all(axis=1)
]
combined_df
# Out:
#               Date           Name Symbol      Open      High       Low  \
# 0       2020-12-25  1inch-Network  1INCH  1.602781  2.918094  1.375262
# 1       2020-12-26  1inch-Network  1INCH  2.318946  2.434916  1.582264
# 2       2020-12-27  1inch-Network  1INCH  1.597744  1.630781  1.056657
# 3       2020-12-28  1inch-Network  1INCH  1.064454  1.254447  1.049051
# 4       2020-12-29  1inch-Network  1INCH  1.110460  1.111282  0.761151
# ...            ...            ...    ...       ...       ...       ...
# 1120381 2023-05-21       Zynecoin    ZYN  0.200783  0.202872  0.170214
# 1120382 2023-05-22       Zynecoin    ZYN  0.192269  0.224723  0.185978
# 1120383 2023-05-23       Zynecoin    ZYN  0.220390  0.234141  0.185507
# 1120384 2023-05-24       Zynecoin    ZYN  0.218146  0.222411  0.196359
# 1120385 2023-05-25       Zynecoin    ZYN  0.199944  0.219885  0.192364
#
#             Close  Adj Close     Volume
# 0        2.328544   2.328544  638225549
# 1        1.596896   1.596896  237653073
# 2        1.062112   1.062112  183978307
# 3        1.110076   1.110076  119337529
# 4        0.887798   0.887798  137916899
# ...           ...        ...        ...
# 1120381  0.192276   0.192276      32333
# 1120382  0.220389   0.220389      20047
# 1120383  0.218141   0.218141      21877
# 1120384  0.200213   0.200213      19095
# 1120385  0.193309   0.193309      29634
#
# [1099666 rows x 9 columns]

# %%
combined_df.describe()
# Out:
#                                 Date          Open          High  \
# count                        1099666  1.099666e+06  1.099666e+06
# mean   2021-06-14 18:59:32.664426752  2.935684e+02  3.178413e+02
# min              2014-09-17 00:00:00  5.583046e-12  5.594990e-12
# 25%              2020-07-21 00:00:00  2.689925e-02  2.850625e-02
# 50%              2021-10-06 00:00:00  2.281455e-01  2.405255e-01
# 75%              2022-08-12 00:00:00  1.539448e+00  1.632826e+00
# max              2023-05-25 00:00:00  1.710106e+05  1.453542e+07
# std                              NaN  3.388190e+03  1.430544e+04
#
#                 Low         Close     Adj Close        Volume
# count  1.099666e+06  1.099666e+06  1.099666e+06  1.099666e+06
# mean   2.827315e+02  2.936960e+02  2.936960e+02  3.586507e+08
# min    5.422281e-12  5.590536e-12  5.590536e-12  1.000000e+00
# 25%    2.542525e-02  2.687900e-02  2.687900e-02  2.696198e+05
# 50%    2.161125e-01  2.279415e-01  2.279415e-01  1.842965e+06
# 75%    1.454594e+00  1.537353e+00  1.537353e+00  1.195011e+07
# max    1.486707e+05  1.709341e+05  1.709341e+05  8.325207e+13
# std    3.249853e+03  3.389041e+03  3.389041e+03  1.087913e+11

# %%
total_volume = combined_df.groupby('Symbol')['Volume'].sum().sort_values(ascending=False)
total_volume
# Out:
# Symbol
# USDC      164718081091523
# USDT       81939262193338
# BTC        52663447875235
# ETH        25437259390713
# BUSD        5390629292485
#                ...
# VDAI               256177
# VLTC               249898
# QOM                142481
# VXVS               141508
# SHIRYO               5456
# Name: Volume, Length: 1000, dtype: int64

# %%
average_close = combined_df.groupby('Symbol')['Close'].mean().sort_values(ascending=False)
average_close.head
# Out:
# <bound method NDFrame.head of Symbol
# SOCKS       5.433760e+04
# HBTC        3.486703e+04
# RENBTC      3.254622e+04
# BTCB        2.579941e+04
# WBTC        2.400649e+04
#                 ...
# HAM         2.282282e-09
# BABYDOGE    1.945511e-09
# QUACK       9.145267e-10
# PIT         3.925129e-10
# SHIRYO      5.590536e-12
# Name: Close, Length: 1000, dtype: float64>

# %%
highest_price = combined_df.groupby('Symbol')['High'].max().sort_values(ascending=False)
highest_price
# Out:
# Symbol
# ZNN         1.453542e+07
# SOCKS       1.988692e+05
# WBTC        1.621882e+05
# RBTC        1.463250e+05
# RENBTC      9.943938e+04
#                 ...
# HAM         2.318388e-09
# BABYDOGE    1.969769e-09
# QUACK       9.308745e-10
# PIT         4.081604e-10
# SHIRYO      5.594990e-12
# Name: High, Length: 1000, dtype: float64

# %%
highest_price_coin = combined_df.groupby('Symbol')['Close'].max()
highest_price_coin.head(10)

hpc_top_10 = highest_price_coin.sort_values(ascending=False).head(10)

# %%
# visualization of top total volume
px.bar(total_volume.head(10).reset_index(), x='Symbol', y='Volume', title='Top 10 Cryptos by Volume')

# %%
# visualization of top closing price
px.bar(average_close.head(10).reset_index(), x='Symbol', y='Close', title='Top 10 Cryptos by Avg Closing Price')

# %%
# visualization of top highest recorded prices
px.bar(highest_price.head(10).reset_index(), x='Symbol', y='High', title='Top 10 Highest Recorded Prices')

# %%
px.bar(hpc_top_10.reset_index(), x='Symbol', y='Close', title='Highest Closing Price', labels={'Close': 'Highest Closing Price (USD)'})

# %%
coins = ['ETH', 'BNB', 'XRP', 'ADA', 'DOGE', 'MATIC', 'SOL']
data = combined_df[combined_df['Symbol'].isin(coins)]
data
# Out:
#               Date     Name Symbol      Open      High       Low     Close  \
# 8619    2017-11-09  Cardano    ADA  0.025160  0.035060  0.025006  0.032053
# 8620    2017-11-10  Cardano    ADA  0.032219  0.033348  0.026451  0.027119
# 8621    2017-11-11  Cardano    ADA  0.026891  0.029659  0.025684  0.027437
# 8622    2017-11-12  Cardano    ADA  0.027480  0.027952  0.022591  0.023977
# 8623    2017-11-13  Cardano    ADA  0.024364  0.026300  0.023495  0.025808
# ...            ...      ...    ...       ...       ...       ...       ...
# 1086648 2023-05-21      XRP    XRP  0.469075  0.470622  0.456592  0.457550
# 1086649 2023-05-22      XRP    XRP  0.457575  0.466325  0.452150  0.461601
# 1086650 2023-05-23      XRP    XRP  0.461609  0.466837  0.459444  0.465430
# 1086651 2023-05-24      XRP    XRP  0.465441  0.465441  0.447464  0.453609
# 1086652 2023-05-25      XRP    XRP  0.453579  0.453913  0.445622  0.449566
#
#          Adj Close      Volume
# 8619      0.032053    18716200
# 8620      0.027119     6766780
# 8621      0.027437     5532220
# 8622      0.023977     7280250
# 8623      0.025808     4419440
# ...            ...         ...
# 1086648   0.457550   537234089
# 1086649   0.461601   904918280
# 1086650   0.465430   829964870
# 1086651   0.453609  1029450864
# 1086652   0.449566   707729920
#
# [12750 rows x 9 columns]

# %%
px.line(data, x='Date', y='Close', color='Symbol', title='Popular Altcoin Trends')

# %%
summary_stats = combined_df.groupby('Symbol')['Close'].agg(['mean', 'median', 'min', 'max', 'std'])
summary_stats = summary_stats.sort_values(by='mean', ascending=False)
summary_stats
# Out:
#                   mean        median           min           max           std
# Symbol
# SOCKS     5.433760e+04  4.050564e+04  2.492046e+03  1.709341e+05  38360.800902
# HBTC      3.486703e+04  3.365155e+04  1.025878e+04  6.779095e+04  13839.195482
# RENBTC    3.254622e+04  3.100577e+04  9.316123e+03  6.749495e+04  14696.939790
# BTCB      2.579941e+04  2.106568e+04  4.936755e+03  6.750242e+04  16411.003892
# WBTC      2.400649e+04  1.954768e+04  3.395979e+03  6.754923e+04  16698.357521
# ...                ...           ...           ...           ...           ...
# HAM       2.282282e-09  2.282282e-09  2.282282e-09  2.282282e-09           NaN
# BABYDOGE  1.945511e-09  1.945511e-09  1.945511e-09  1.945511e-09           NaN
# QUACK     9.145267e-10  9.145267e-10  9.145267e-10  9.145267e-10           NaN
# PIT       3.925129e-10  3.925129e-10  3.925129e-10  3.925129e-10           NaN
# SHIRYO    5.590536e-12  5.590536e-12  5.590536e-12  5.590536e-12           NaN
#
# [1000 rows x 5 columns]

# %%
# search for std NaN values
missing_std = summary_stats[summary_stats['std'].isna()]
print(missing_std)
# Out:
#                    mean        median           min           max  std
# Symbol
# QOM        3.546230e-08  3.546230e-08  3.546230e-08  3.546230e-08  NaN
# VINU15270  9.437173e-09  9.437173e-09  9.437173e-09  9.437173e-09  NaN
# HAM        2.282282e-09  2.282282e-09  2.282282e-09  2.282282e-09  NaN
# BABYDOGE   1.945511e-09  1.945511e-09  1.945511e-09  1.945511e-09  NaN
# QUACK      9.145267e-10  9.145267e-10  9.145267e-10  9.145267e-10  NaN
# PIT        3.925129e-10  3.925129e-10  3.925129e-10  3.925129e-10  NaN
# SHIRYO     5.590536e-12  5.590536e-12  5.590536e-12  5.590536e-12  NaN

# %%
# std coloumn data cleaning
summary_stats_clean = summary_stats.dropna(subset=['std'])
summary_stats_clean
# Out:
#                    mean        median           min           max  \
# Symbol
# SOCKS      5.433760e+04  4.050564e+04  2.492046e+03  1.709341e+05
# HBTC       3.486703e+04  3.365155e+04  1.025878e+04  6.779095e+04
# RENBTC     3.254622e+04  3.100577e+04  9.316123e+03  6.749495e+04
# BTCB       2.579941e+04  2.106568e+04  4.936755e+03  6.750242e+04
# WBTC       2.400649e+04  1.954768e+04  3.395979e+03  6.754923e+04
# ...                 ...           ...           ...           ...
# YOOSHI     1.495460e-06  1.000000e-06  6.869308e-08  3.000000e-06
# ELON       1.194040e-06  1.000000e-06  1.961043e-07  2.000000e-06
# VOLT19650  1.151814e-06  1.000000e-06  5.737135e-07  3.000000e-06
# BRISE      1.001640e-06  1.000000e-06  2.886614e-07  2.000000e-06
# LOVELY     8.968987e-07  1.000000e-06  7.208801e-08  1.000000e-06
#
#                     std
# Symbol
# SOCKS      3.836080e+04
# HBTC       1.383920e+04
# RENBTC     1.469694e+04
# BTCB       1.641100e+04
# WBTC       1.669836e+04
# ...                 ...
# YOOSHI     6.320070e-07
# ELON       4.054396e-07
# VOLT19650  3.882243e-07
# BRISE      9.275249e-08
# LOVELY     3.093040e-07
#
# [993 rows x 5 columns]

# %%
top_mean = summary_stats_clean.sort_values('mean', ascending=False).head(10)

import plotly.express as px
px.bar(top_mean.reset_index(), x='Symbol', y='mean', title='Top 10 Tokens by Average Closing Price')

# %%
# volatility check
top_std = summary_stats_clean.dropna(subset=['std']).sort_values('std', ascending=False).head(10)

px.bar(top_std.reset_index(), x='Symbol', y='std', title='Top 10 Most Volatile Tokens')
